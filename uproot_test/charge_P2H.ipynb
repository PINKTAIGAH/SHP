# %%
import numpy as np
import awkward as ak
import uproot
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy import integrate

# %%
# root_file_dir= '~/Desktop/Root_files/'
root_file_dir= '~/Desktop/Data/P2H_charge/'
P2H_area= [1750,1800,1850,1900,1950,2000,2050,2100]

# %%
file1750= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_1.root:Events')
file1800= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_1.root:Events')
file1850= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_1.root:Events')
file1900= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_1.root:Events')
file1950= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_1.root:Events')
file2000= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_1.root:Events')
file2050= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_1.root:Events')
file2100= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_1.root:Events')


files_list= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# file50.keys(filter_name='**')

# %%
file1750_1= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_1.root:Events')
file1800_1= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_1.root:Events')
file1850_1= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_1.root:Events')
file1900_1= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_1.root:Events')
file1950_1= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_1.root:Events')
file2000_1= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_1.root:Events')
file2050_1= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_1.root:Events')
file2100_1= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_1.root:Events')


files_list_1= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# %%
file1750_2= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_2.root:Events')
file1800_2= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_2.root:Events')
file1850_2= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_2.root:Events')
file1900_2= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_2.root:Events')
file1950_2= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_2.root:Events')
file2000_2= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_2.root:Events')
file2050_2= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_2.root:Events')
file2100_2= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_2.root:Events')


files_list_2= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# %%
file1750_3= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_3.root:Events')
file1800_3= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_3.root:Events')
file1850_3= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_3.root:Events')
file1900_3= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_3.root:Events')
file1950_3= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_3.root:Events')
file2000_3= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_3.root:Events')
file2050_3= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_3.root:Events')
file2100_3= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_3.root:Events')


files_list_3= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# %%
file1750_4= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_4.root:Events')
file1800_4= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_4.root:Events')
file1850_4= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_4.root:Events')
file1900_4= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_4.root:Events')
file1950_4= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_4.root:Events')
file2000_4= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_4.root:Events')
file2050_4= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_4.root:Events')
file2100_4= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_4.root:Events')


files_list_4= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# %%
file1750_5= uproot.open(root_file_dir + 'output_P2H_1750_nevents_10_detsim_5.root:Events')
file1800_5= uproot.open(root_file_dir + 'output_P2H_1800_nevents_10_detsim_5.root:Events')
file1850_5= uproot.open(root_file_dir + 'output_P2H_1850_nevents_10_detsim_5.root:Events')
file1900_5= uproot.open(root_file_dir + 'output_P2H_1900_nevents_10_detsim_5.root:Events')
file1950_5= uproot.open(root_file_dir + 'output_P2H_1950_nevents_10_detsim_5.root:Events')
file2000_5= uproot.open(root_file_dir + 'output_P2H_2000_nevents_10_detsim_5.root:Events')
file2050_5= uproot.open(root_file_dir + 'output_P2H_2050_nevents_10_detsim_5.root:Events')
file2100_5= uproot.open(root_file_dir + 'output_P2H_2100_nevents_10_detsim_5.root:Events')


files_list_5= [file1750, file1800, file1850, file1900, file1950, file2000, file2050, file2100]

# %%
files_full_list= [files_list_1, files_list_2, files_list_3, files_list_4, files_list_5]

# %%
def find_hist(array):
    count,bin, _= plt.hist(array)
    return count, bin[:-1]+bin[0]/2

def find_integral_1f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(files_full_list[i][k][str(name)].array()).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

def find_integral_2f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(ak.flatten(files_full_list[i][k][str(name)].array())).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

def find_integral_3f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(ak.flatten(ak.flatten(files_full_list[i][k][str(name)].array()))).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

# %%
rr_name= 'sim::AuxDetIDEs_crtsim__DetSim./sim::AuxDetIDEs_crtsim__DetSim.obj/sim::AuxDetIDEs_crtsim__DetSim.obj.energyDeposited'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(file1750[str(rr_name)].array()).to_numpy()
a2000= ak.flatten(file2000[str(rr_name)].array()).to_numpy()
a2100= ak.flatten(file2100[str(rr_name)].array()).to_numpy()
a1900= ak.flatten(file1900[str(rr_name)].array()).to_numpy()

# a150= a150[a150>0.0005]
# a50= a50[a50>0.0005]
# a700= a700[a700>0.005]
# a350= a350[a350>0.005]

axs[0][0].hist(a1750[a1750<0.0002], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][1].hist(a1900[a1900<0.0002], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][0].hist(a2000[a2000<0.0002], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][1].hist(a2100[a2100<0.0002], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Energy deposited, E$_{dep}$ (MeV)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of Energy deposited in CRT', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of Energy deposited in CRT')

# %%
rr_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numElectrons'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(file1750[str(rr_name)].array()).to_numpy()
a2000= ak.flatten(file2000[str(rr_name)].array()).to_numpy()
a2100= ak.flatten(file2100[str(rr_name)].array()).to_numpy()
a1900= ak.flatten(file1900[str(rr_name)].array()).to_numpy()

a1750= a1750[a1750>200]
a1900= a1900[a1900>200]
a2100= a2100[a2100>200]
a2000= a2000[a2000>200]

axs[0][0].hist(a1750[a1750<2000], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][1].hist(a1900[a1900<2000], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][0].hist(a2000[a2000<2000], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][1].hist(a2100[a2100<2000], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()

fig.supxlabel(r'Number of electrons', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of number of electrons inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of number of electrons inside TPC')

# %%
rr_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numPhotons'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(file1750[str(rr_name)].array()).to_numpy()
a1900= ak.flatten(file1900[str(rr_name)].array()).to_numpy()
a2000= ak.flatten(file2000[str(rr_name)].array()).to_numpy()
a2100= ak.flatten(file2100[str(rr_name)].array()).to_numpy()

# a150= a150[a150>200]
# a50= a50[a50>200]
# a700= a700[a700>200]
# a350= a350[a350>200]

axs[0][0].hist(a1750[a1750<200], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][1].hist(a1900[a1900<200], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][0].hist(a2000[a2000<200], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][1].hist(a2100[a2100<200], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'Number of photons', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of number of photons inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of number of photons inside TPC')

# %%
rr_name= 'sbnd::crt::CRTDatas_crt__DetSim./sbnd::crt::CRTDatas_crt__DetSim.obj/sbnd::crt::CRTDatas_crt__DetSim.obj.fADC'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(file1750[str(rr_name)].array()).to_numpy()
a1900= ak.flatten(file1900[str(rr_name)].array()).to_numpy()
a2000= ak.flatten(file2000[str(rr_name)].array()).to_numpy()
a2100= ak.flatten(file2100[str(rr_name)].array()).to_numpy()


axs[0][0].hist(a1750[:], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][1].hist(a1900[:], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][0].hist(a2000[:], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][1].hist(a2100[:], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'ADC value', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of ADC value', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of ADC value')

# %%
rr_name=  'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fmass'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(file1750[str(rr_name)].array()).to_numpy()
a1900= ak.flatten(file1900[str(rr_name)].array()).to_numpy()
a2000= ak.flatten(file2000[str(rr_name)].array()).to_numpy()
a2100= ak.flatten(file2100[str(rr_name)].array()).to_numpy()
axs[0][1].hist(a1750[a1750<40], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][0].hist(a1900[a1900<40], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][1].hist(a2000[a2000<40], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][0].hist(a2100[a2100<40], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'mass, m (Mevc$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of mass of particles inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of mass of particles inside TPC')

# %%
rr_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdQdx'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(ak.flatten(ak.flatten(file1750[str(rr_name)].array()))).to_numpy()
a1900= ak.flatten(ak.flatten(ak.flatten(file1900[str(rr_name)].array()))).to_numpy()
a2000= ak.flatten(ak.flatten(ak.flatten(file2000[str(rr_name)].array()))).to_numpy()
a2100= ak.flatten(ak.flatten(ak.flatten(file2100[str(rr_name)].array()))).to_numpy()

a1750= a1750[a1750>30000]
a1900= a1900[a1900>30000]
a2000= a2000[a2000>30000]
a2100= a2100[a2100>30000]

axs[0][1].hist(a1750[a1750<75000], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][0].hist(a1900[a1900<75000], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][1].hist(a2000[a2000<75000], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][0].hist(a2100[a2100<75000], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Stopping charge, $\frac{dQ}{dx}$ (ADCcm$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of stopping charge of tracks in TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of stopping charge of tracks in TPC')

# %%
rr_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdEdx'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a1750= ak.flatten(ak.flatten(file1750[str(rr_name)].array())).to_numpy()
a1900= ak.flatten(ak.flatten(file1900[str(rr_name)].array())).to_numpy()
a2000= ak.flatten(ak.flatten(file2000[str(rr_name)].array())).to_numpy()
a2100= ak.flatten(ak.flatten(file2100[str(rr_name)].array())).to_numpy()

a1750= a1750[a1750>0.5]
a1900= a1900[a1900>0.5]
a2000= a2000[a2000>0.5]
a2100= a2100[a2100>0.5]

axs[0][1].hist(a1750[a1750<2], bins=100, label='P2H = 1750', alpha= 0.3, color='k')
axs[0][0].hist(a1900[a1900<2], bins=100, label='P2H = 1900', alpha= 0.3, color='r')
axs[1][1].hist(a2000[a2000<2], bins=100, label='P2H = 2000', alpha= 0.3, color='g')
axs[1][0].hist(a2100[a2100<2], bins=100, label='P2H = 2100', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
# axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Stopping energy, $\frac{dE}{dx}$ (MeVcm$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of stopping energy of tracks in TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of stopping energy of tracks in TPC')

# %%
Edep_name= 'sim::AuxDetIDEs_crtsim__DetSim./sim::AuxDetIDEs_crtsim__DetSim.obj/sim::AuxDetIDEs_crtsim__DetSim.obj.energyDeposited'
nele_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numElectrons'
npho_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numPhotons'
ADC_name= 'sbnd::crt::CRTDatas_crt__DetSim./sbnd::crt::CRTDatas_crt__DetSim.obj/sbnd::crt::CRTDatas_crt__DetSim.obj.fADC'
daughter_name= 'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fdaughters'
mass_name=  'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fmass'
dqdx_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdQdx'
dedx_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdEdx'

# %%
integral_Edep=find_integral_1f(str(Edep_name))
integral_nele=find_integral_1f(str(nele_name))
# integral_npho=find_integral_1f(str(npho_name))
# integral_ADC=find_integral_1f(str(ADC_name))
# integral_daughter=find_integral_2f(str(daughter_name))
# integral_mass=find_integral_1f(str(mass_name))
# integral_dqdx=find_integral_3f(str(dqdx_name))
integral_dedx=find_integral_2f(str(dedx_name))

# %%
e_integral_Edep= np.std(np.array(integral_Edep)/np.sqrt(10), axis=0)
e_integral_nele= np.std(np.array(integral_nele)/np.sqrt(10), axis=0)
# e_integral_npho= np.std(np.array(integral_npho)/np.sqrt(10), axis=0)
# e_integral_ADC= np.std(np.array(integral_ADC)/np.sqrt(10), axis=0)
# e_integral_daughter= np.std(np.array(integral_daughter)/np.sqrt(10), axis=0)
# e_integral_mass= np.std(np.array(integral_mass)/np.sqrt(10), axis=0)
# e_integral_dqdx= np.std(np.array(integral_dqdx)/np.sqrt(10), axis=0)
e_integral_dedx= np.std(np.array(integral_dedx)/np.sqrt(10), axis=0)

integral_Edep= np.average(np.array(integral_Edep), axis=0)
integral_nele= np.average(np.array(integral_nele), axis=0)
# integral_npho= np.average(np.array(integral_npho), axis=0)
# integral_ADC= np.average(np.array(integral_ADC), axis=0)
# integral_daughter= np.average(np.array(integral_daughter), axis=0)
# integral_mass= np.average(np.array(integral_mass), axis=0)
# integral_dqdx= np.average(np.array(integral_dqdx), axis=0)
integral_dedx= np.average(np.array(integral_dedx), axis=0)

# %%
plt.errorbar(P2H_area, integral_Edep/integral_Edep[2], yerr=e_integral_Edep,  c= 'r', label='Energy deposit')
plt.errorbar(P2H_area, integral_nele/integral_nele[2], yerr=e_integral_nele, c= 'g', label=r'number of e$^-$')
# plt.errorbar(P2H_area, integral_npho/max(integral_npho), yerr=e_integral_npho, c= 'b', label=r'number of $\gamma$')
# plt.errorbar(P2H_area, integral_ADC/max(integral_ADC), yerr=e_integral_ADC, c= 'm', label='ADC')
# plt.errorbar(P2H_area, integral_daughter/max(integral_daughter), yerr=e_integral_daughter, c= 'y', label='daughter number')
# plt.errorbar(P2H_area, integral_mass/max(integral_mass), yerr=e_integral_mass,c= 'c', label='particle mass')
# plt.errorbar(P2H_area, integral_dqdx/max(integral_dqdx), yerr=e_integral_dqdx,c= 'k', label='dqdx')
plt.errorbar(P2H_area, integral_dedx/integral_dedx[2], yerr=e_integral_dedx,c= 'k', label='dedx')
plt.tight_layout()
# axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel(r'Project to Height length, P2H (cm)', y=-0.05)
plt.ylabel('Integral ratio of histogram', x=-0.02)
plt.axvline(1850, color='m', linestyle= '--', label= 'Default parameter')
# plt.title('Plot of histogram integral vs boundary box size', y=1.02)
plt.legend()

# %% [markdown]
# look at ratio of muons thart leave tpc and which dont
# look at angle incidence
