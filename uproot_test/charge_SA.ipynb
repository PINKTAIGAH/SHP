# %%
import numpy as np
import awkward as ak
import uproot
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy import integrate

# %%
# root_file_dir= '~/Desktop/Root_files/'
root_file_dir= '~/Desktop/Data/SA_charge/'
SA_area= [800,850,900,950,1000,1050,1100,1150]

# %%
file800= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_1.root:Events')
file850= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_1.root:Events')
file900= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_1.root:Events')
file950= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_1.root:Events')
file1000= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_1.root:Events')
file1050= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_1.root:Events')
file1100= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_1.root:Events')
file1150= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_1.root:Events')


files_list= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# file50.keys(filter_name='**')

# %%
file800_1= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_1.root:Events')
file850_1= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_1.root:Events')
file900_1= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_1.root:Events')
file950_1= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_1.root:Events')
file1000_1= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_1.root:Events')
file1050_1= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_1.root:Events')
file1100_1= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_1.root:Events')
file1150_1= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_1.root:Events')


files_list_1= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# %%
file800_2= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_2.root:Events')
file850_2= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_2.root:Events')
file900_2= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_2.root:Events')
file950_2= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_2.root:Events')
file1000_2= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_2.root:Events')
file1050_2= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_2.root:Events')
file1100_2= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_2.root:Events')
file1150_2= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_2.root:Events')


files_list_2= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# %%
file800_3= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_3.root:Events')
file850_3= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_3.root:Events')
file900_3= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_3.root:Events')
file950_3= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_3.root:Events')
file1000_3= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_3.root:Events')
file1050_3= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_3.root:Events')
file1100_3= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_3.root:Events')
file1150_3= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_3.root:Events')


files_list_3= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# %%
file800_4= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_4.root:Events')
file850_4= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_4.root:Events')
file900_4= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_4.root:Events')
file950_4= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_4.root:Events')
file1000_4= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_4.root:Events')
file1050_4= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_4.root:Events')
file1100_4= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_4.root:Events')
file1150_4= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_4.root:Events')


files_list_4= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# %%
file800_5= uproot.open(root_file_dir + 'output_SA_0800_nevents_10_detsim_5.root:Events')
file850_5= uproot.open(root_file_dir + 'output_SA_0850_nevents_10_detsim_5.root:Events')
file900_5= uproot.open(root_file_dir + 'output_SA_0900_nevents_10_detsim_5.root:Events')
file950_5= uproot.open(root_file_dir + 'output_SA_0950_nevents_10_detsim_5.root:Events')
file1000_5= uproot.open(root_file_dir + 'output_SA_1000_nevents_10_detsim_5.root:Events')
file1050_5= uproot.open(root_file_dir + 'output_SA_1050_nevents_10_detsim_5.root:Events')
file1100_5= uproot.open(root_file_dir + 'output_SA_1100_nevents_10_detsim_5.root:Events')
file1150_5= uproot.open(root_file_dir + 'output_SA_1150_nevents_10_detsim_5.root:Events')


files_list_5= [file800, file850, file900, file950, file1000, file1050, file1100, file1150]

# %%
files_full_list= [files_list_1, files_list_2, files_list_3, files_list_4, files_list_5]

# %%
def find_hist(array):
    count,bin, _= plt.hist(array)
    return count, bin[:-1]+bin[0]/2

def find_integral_1f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(files_full_list[i][k][str(name)].array()).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

def find_integral_2f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(ak.flatten(files_full_list[i][k][str(name)].array())).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

def find_integral_3f(name):
    integral_total=[]
    for i in range(len(files_full_list)):
        arrays= [ak.flatten(ak.flatten(ak.flatten(files_full_list[i][k][str(name)].array()))).to_numpy() for k in range(len(files_list))]
        counts= []
        bins= []
        for j in range(len(arrays)):
            c,b= find_hist(arrays[j])
            counts.append(c)
            bins.append(b)
        plt.clf()

        integral= [integrate.simpson(counts[l], bins[l]) for l in range(len(arrays))]
        integral_total.append(integral)   
    return integral_total

# %%
rr_name= 'sim::AuxDetIDEs_crtsim__DetSim./sim::AuxDetIDEs_crtsim__DetSim.obj/sim::AuxDetIDEs_crtsim__DetSim.obj.energyDeposited'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(file800[str(rr_name)].array()).to_numpy()
a1050= ak.flatten(file1050[str(rr_name)].array()).to_numpy()
a1150= ak.flatten(file1150[str(rr_name)].array()).to_numpy()
a950= ak.flatten(file950[str(rr_name)].array()).to_numpy()

# a150= a150[a150>0.0005]
# a50= a50[a50>0.0005]
# a700= a700[a700>0.005]
# a350= a350[a350>0.005]

axs[0][0].hist(a800[a800<0.0002], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][1].hist(a950[a950<0.0002], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][0].hist(a1050[a1050<0.0002], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][1].hist(a1150[a1150<0.0002], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Energy deposited, E$_{dep}$ (MeV)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of Energy deposited in CRT', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of Energy deposited in CRT')

# %%
rr_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numElectrons'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(file800[str(rr_name)].array()).to_numpy()
a1050= ak.flatten(file1050[str(rr_name)].array()).to_numpy()
a1150= ak.flatten(file1150[str(rr_name)].array()).to_numpy()
a950= ak.flatten(file950[str(rr_name)].array()).to_numpy()

a800= a800[a800>200]
a950= a950[a950>200]
a1150= a1150[a1150>200]
a1050= a1050[a1050>200]

axs[0][0].hist(a800[a800<1050], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][1].hist(a950[a950<1050], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][0].hist(a1050[a1050<1050], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][1].hist(a1150[a1150<1050], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()

fig.supxlabel(r'Number of electrons', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of number of electrons inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of number of electrons inside TPC')

# %%
rr_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numPhotons'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(file800[str(rr_name)].array()).to_numpy()
a950= ak.flatten(file950[str(rr_name)].array()).to_numpy()
a1050= ak.flatten(file1050[str(rr_name)].array()).to_numpy()
a1150= ak.flatten(file1150[str(rr_name)].array()).to_numpy()

# a150= a150[a150>200]
# a50= a50[a50>200]
# a700= a700[a700>200]
# a350= a350[a350>200]

axs[0][0].hist(a800[a800<200], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][1].hist(a950[a950<200], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][0].hist(a1050[a1050<200], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][1].hist(a1150[a1150<200], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'Number of photons', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of number of photons inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of number of photons inside TPC')

# %%
rr_name= 'sbnd::crt::CRTDatas_crt__DetSim./sbnd::crt::CRTDatas_crt__DetSim.obj/sbnd::crt::CRTDatas_crt__DetSim.obj.fADC'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(file800[str(rr_name)].array()).to_numpy()
a950= ak.flatten(file950[str(rr_name)].array()).to_numpy()
a1050= ak.flatten(file1050[str(rr_name)].array()).to_numpy()
a1150= ak.flatten(file1150[str(rr_name)].array()).to_numpy()


axs[0][0].hist(a800[:], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][1].hist(a950[:], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][0].hist(a1050[:], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][1].hist(a1150[:], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'ADC value', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of ADC value', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of ADC value')

# %%
rr_name=  'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fmass'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(file800[str(rr_name)].array()).to_numpy()
a950= ak.flatten(file950[str(rr_name)].array()).to_numpy()
a1050= ak.flatten(file1050[str(rr_name)].array()).to_numpy()
a1150= ak.flatten(file1150[str(rr_name)].array()).to_numpy()
axs[0][1].hist(a800[a800<40], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][0].hist(a950[a950<40], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][1].hist(a1050[a1050<40], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][0].hist(a1150[a1150<40], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
fig.supxlabel(r'mass, m (Mevc$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of mass of particles inside TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of mass of particles inside TPC')

# %%
rr_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdQdx'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(ak.flatten(ak.flatten(file800[str(rr_name)].array()))).to_numpy()
a950= ak.flatten(ak.flatten(ak.flatten(file950[str(rr_name)].array()))).to_numpy()
a1050= ak.flatten(ak.flatten(ak.flatten(file1050[str(rr_name)].array()))).to_numpy()
a1150= ak.flatten(ak.flatten(ak.flatten(file1150[str(rr_name)].array()))).to_numpy()

a800= a800[a800>30000]
a950= a950[a950>30000]
a1050= a1050[a1050>30000]
a1150= a1150[a1150>30000]

axs[0][1].hist(a800[a800<75000], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][0].hist(a950[a950<75000], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][1].hist(a1050[a1050<75000], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][0].hist(a1150[a1150<75000], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Stopping charge, $\frac{dQ}{dx}$ (ADCcm$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of stopping charge of tracks in TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of stopping charge of tracks in TPC')

# %%
rr_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdEdx'
fig,axs= plt.subplots(2,2, sharey=True, sharex= True)
a800= ak.flatten(ak.flatten(file800[str(rr_name)].array())).to_numpy()
a950= ak.flatten(ak.flatten(file950[str(rr_name)].array())).to_numpy()
a1050= ak.flatten(ak.flatten(file1050[str(rr_name)].array())).to_numpy()
a1150= ak.flatten(ak.flatten(file1150[str(rr_name)].array())).to_numpy()

a800= a800[a800>0.5]
a950= a950[a950>0.5]
a1050= a1050[a1050>0.5]
a1150= a1150[a1150>0.5]

axs[0][1].hist(a800[a800<2], bins=100, label='SA = 800', alpha= 0.3, color='k')
axs[0][0].hist(a950[a950<2], bins=100, label='SA = 950', alpha= 0.3, color='r')
axs[1][1].hist(a1050[a1050<2], bins=100, label='SA = 1050', alpha= 0.3, color='g')
axs[1][0].hist(a1150[a1150<2], bins=100, label='SA = 1150', alpha= 0.3, color='m')
axs[0][0].legend()
axs[0][1].legend()
axs[1][0].legend()
axs[1][1].legend()
fig.tight_layout()
# axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
fig.supxlabel(r'Stopping energy, $\frac{dE}{dx}$ (MeVcm$^{-1}$)', y=-0.05)
fig.supylabel('Frequency (count)', x=-0.02)
fig.suptitle('Histogram of stopping energy of tracks in TPC', y=1.05)
# Out:
# Text(0.5, 1.05, 'Histogram of stopping energy of tracks in TPC')

# %%
Edep_name= 'sim::AuxDetIDEs_crtsim__DetSim./sim::AuxDetIDEs_crtsim__DetSim.obj/sim::AuxDetIDEs_crtsim__DetSim.obj.energyDeposited'
nele_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numElectrons'
npho_name= 'sim::SimEnergyDeposits_ionandscintout__G4./sim::SimEnergyDeposits_ionandscintout__G4.obj/sim::SimEnergyDeposits_ionandscintout__G4.obj.numPhotons'
ADC_name= 'sbnd::crt::CRTDatas_crt__DetSim./sbnd::crt::CRTDatas_crt__DetSim.obj/sbnd::crt::CRTDatas_crt__DetSim.obj.fADC'
daughter_name= 'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fdaughters'
mass_name=  'simb::MCParticles_largeant__G4./simb::MCParticles_largeant__G4.obj/simb::MCParticles_largeant__G4.obj.fmass'
dqdx_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdQdx'
dedx_name=  'sim::MCTracks_mcreco__G4./sim::MCTracks_mcreco__G4.obj/sim::MCTracks_mcreco__G4.obj.fdEdx'

# %%
integral_Edep=find_integral_1f(str(Edep_name))
integral_nele=find_integral_1f(str(nele_name))
# integral_npho=find_integral_1f(str(npho_name))
# integral_ADC=find_integral_1f(str(ADC_name))
# integral_daughter=find_integral_2f(str(daughter_name))
# integral_mass=find_integral_1f(str(mass_name))
# integral_dqdx=find_integral_3f(str(dqdx_name))
integral_dedx=find_integral_2f(str(dedx_name))

# %%
e_integral_Edep= np.std(np.array(integral_Edep)/np.sqrt(10), axis=0)
e_integral_nele= np.std(np.array(integral_nele)/np.sqrt(10), axis=0)
# e_integral_npho= np.std(np.array(integral_npho)/np.sqrt(10), axis=0)
# e_integral_ADC= np.std(np.array(integral_ADC)/np.sqrt(10), axis=0)
# e_integral_daughter= np.std(np.array(integral_daughter)/np.sqrt(10), axis=0)
# e_integral_mass= np.std(np.array(integral_mass)/np.sqrt(10), axis=0)
# e_integral_dqdx= np.std(np.array(integral_dqdx)/np.sqrt(10), axis=0)
e_integral_dedx= np.std(np.array(integral_dedx)/np.sqrt(10), axis=0)

integral_Edep= np.average(np.array(integral_Edep), axis=0)
integral_nele= np.average(np.array(integral_nele), axis=0)
# integral_npho= np.average(np.array(integral_npho), axis=0)
# integral_ADC= np.average(np.array(integral_ADC), axis=0)
# integral_daughter= np.average(np.array(integral_daughter), axis=0)
# integral_mass= np.average(np.array(integral_mass), axis=0)
# integral_dqdx= np.average(np.array(integral_dqdx), axis=0)
integral_dedx= np.average(np.array(integral_dedx), axis=0)

# %%
plt.errorbar(SA_area, integral_Edep/integral_Edep[4], yerr=e_integral_Edep,  c= 'r', label='Energy deposit')
plt.errorbar(SA_area, integral_nele/integral_nele[4], yerr=e_integral_nele, c= 'g', label=r'number of e$^-$')
# plt.errorbar(SA_area, integral_npho/max(integral_npho), yerr=e_integral_npho, c= 'b', label=r'number of $\gamma$')
# plt.errorbar(SA_area, integral_ADC/max(integral_ADC), yerr=e_integral_ADC, c= 'm', label='ADC')
# plt.errorbar(SA_area, integral_daughter/max(integral_daughter), yerr=e_integral_daughter, c= 'y', label='daughter number')
# plt.errorbar(SA_area, integral_mass/max(integral_mass), yerr=e_integral_mass,c= 'c', label='particle mass')
# plt.errorbar(SA_area, integral_dqdx/max(integral_dqdx), yerr=e_integral_dqdx,c= 'k', label='dqdx')
plt.errorbar(SA_area, integral_dedx/integral_dedx[4], yerr=e_integral_dedx,c= 'k', label='dedx')

plt.tight_layout()
# axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel(r'Shower area length, SA (cm)', y=-0.05)
plt.ylabel('Integral ratio of histogram', x=-0.02)
plt.axvline(1000, color='m', linestyle= '--', label= 'Default parameter')
# plt.title('Plot of histogram integral vs boundary box size', y=1.02)
plt.tight_layout()
plt.legend()

# %% [markdown]
# look at ratio of muons thart leave tpc and which dont
# look at angle incidence
